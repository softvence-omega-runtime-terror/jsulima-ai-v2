# %% [markdown]
# ### Step 1: Initial Setup and Data Loading

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("Libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Libraries imported successfully!
# Pandas version: 2.2.2
# NumPy version: 2.0.2

# %% [markdown]
# ### Step 2: Load Historical Fights and Fighter Profiles

# %%
import os

# Check current working directory
print("Current working directory:")
print(os.getcwd())

# Let's try to find the data files
print("\n" + "=" * 80)
print("Looking for data files...")
print("=" * 80)

# Try different path variations
possible_paths = [
    './app/data/raw/historical_fights.csv',
    '../app/data/raw/historical_fights.csv',
    'app/data/raw/historical_fights.csv',
    'data/raw/historical_fights.csv',
    './data/raw/historical_fights.csv',
]

for path in possible_paths:
    if os.path.exists(path):
        print(f"✓ Found: {path}")
    else:
        print(f"✗ Not found: {path}")

# List files in current directory
print("\n" + "=" * 80)
print("Files and directories in current location:")
print("=" * 80)
for item in os.listdir('.'):
    print(f"  {item}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1950985230.py in <cell line: 0>()
#       1 # Load historical fights data
# ----> 2 fights_df = pd.read_csv('../app/data/raw/historical_fights.csv')
#       3
#       4 # Load fighter profiles
#       5 with open('../app/data/processed/fighter_profiles.json', 'r') as f:
#
# ...
